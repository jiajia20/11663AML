# %%
import pandas as pd

# %%
dev = pd.read_csv("dev_data.csv")

# %%
dev_excite = dev[dev["Excite"] == 1]

# %%
dev_excite
# Out:
#      Unnamed: 0  Unnamed: 0.1       Node ID  \
# 3          3222             4  1.322952e+18
# 5          3224             6  1.323103e+18
# 12         3231            13  1.323125e+18
# 14         3233            15  1.323116e+18
# 16         3235            17  1.323126e+18
# ..          ...           ...           ...
# 861        4080            49  1.323126e+18
# 863        4082            51  1.323102e+18
# 871        4090            59  1.323126e+18
# 889        4108            77  1.323126e+18
# 915        4134             3  1.103395e+18
#
#                                                MESSAGE  \
# 3    Black Women for Trump!  President @realDonaldT...
# 5    DID YOU KNOW @realDonaldTrump WAS BORN UNDER A...
# 12   EPIC!  #Trump #Trump2020LandslideVictory   htt...
# 14   LETS GOOOOOO FLORIDA!  Miami is wild!   #MAGA ...
# 16   RT @MaryLTrump: They're trying to keep us from...
# ..                                                 ...
# ...
